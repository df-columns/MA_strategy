# %%
import MA_strategy_longshort as ma_ls
import pandas as pd
import matplotlib.pyplot as plt

# %%
path=r'C:\Users\sw.shin\Downloads\02_TIGER200.xlsx'

# %%
ma_ls.MA_strategy_longshort(path,10,20)
# Out:
# C:\Users\sw.shin\완료된 작업들\잡동사니 연습물\이평선 돌파\MA_strategy_longshort.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['매수신호']='No'
# C:\Users\sw.shin\완료된 작업들\잡동사니 연습물\이평선 돌파\MA_strategy_longshort.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['매도신호']='No'
# C:\Users\sw.shin\완료된 작업들\잡동사니 연습물\이평선 돌파\MA_strategy_longshort.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
ma_ls.MA_strategy_longshort_result(path,10,20)
# Out:
# C:\Users\sw.shin\완료된 작업들\잡동사니 연습물\이평선 돌파\MA_strategy_longshort.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['매수신호']='No'
# C:\Users\sw.shin\완료된 작업들\잡동사니 연습물\이평선 돌파\MA_strategy_longshort.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['매도신호']='No'
# C:\Users\sw.shin\완료된 작업들\잡동사니 연습물\이평선 돌파\MA_strategy_longshort.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
